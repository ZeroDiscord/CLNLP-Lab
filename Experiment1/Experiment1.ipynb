# %% [markdown]
# # Experiment 1: Data Analysis

# %%
import pandas as pd
import seaborn as sns
file_path = '/content/drive/MyDrive/CLNLP Lab/Experiment 1/employee_information_100.csv'

df = pd.read_csv(file_path)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee_ID       100 non-null    object
#  1   Name              100 non-null    object
#  2   Department        100 non-null    object
#  3   Age               100 non-null    int64
#  4   Gender            100 non-null    object
#  5   Salary            100 non-null    int64
#  6   Experience_Years  100 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 5.6+ KB

# %% [markdown]
# ## Experiment 1.1: Average Salary by Department

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
avg_salary = df.groupby('Department')['Salary'].mean().sort_values()
avg_salary.plot(kind="barh")
plt.title('Average Salary by Department')
plt.xlabel('Average Salary')
plt.ylabel('Department')
plt.show()

# %% [markdown]
# ## Experiment 1.2: Number of Employees per Department

# %%
dept_counts = df['Department'].value_counts()
print("Employee counts per department:")
print(dept_counts)

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Department')
plt.title('Number of Employees in Each Department')
plt.show()
# Out:
# Employee counts per department:
# Department
# HR            21
# Marketing     20
# IT            18
# Operations    16
# Sales         13
# Finance       12
# Name: count, dtype: int64

# %% [markdown]
# ## Experiment 1.3: Gender Distribution

# %%
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=['lightblue', 'pink'])
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# ## Experiment 1.4: Salary Distribution Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Salary'], bins=15, kde=True)
plt.title('Distribution of Employee Salaries')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Experiment 1.5: Relationship between Experience and Salary

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Experience_Years', y='Salary', hue='Department', style='Gender')
plt.title('Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Experiment 1.6: Top 10 Highest Paid Employees

# %%
top_10_salaries = df.nlargest(10, 'Salary')[['Name', 'Department', 'Salary', 'Experience_Years']]
print("Top 10 employees with the highest salary:")
display(top_10_salaries)
# Out:
# Top 10 employees with the highest salary:
#          Name  Department  Salary  Experience_Years
# 85     Omar86   Marketing  119000                24
# 87    Diana88   Marketing  119000                33
# 14    Ishan15  Operations  117000                20
# 22    Rahul23     Finance  117000                 7
# 58     Neha59          IT  117000                16
# 48  Charlie49          IT  116000                15
# 31   George32  Operations  115000                23
# 55    Sneha56  Operations  115000                35
# 64      Bob65     Finance  115000                 6
# 9    Vikram10          IT  114000                14

# %% [markdown]
# ## Experiment 1.7: Highest Salary in Every Department

# %%
max_salary_dept = df.groupby('Department')['Salary'].max()
print("Highest salary in each department:")
print(max_salary_dept)
# Out:
# Highest salary in each department:
# Department
# Finance       117000
# HR            113000
# IT            117000
# Marketing     119000
# Operations    117000
# Sales         114000
# Name: Salary, dtype: int64

# %% [markdown]
# ## Experiment 1.8: Employees with Above-Average Salary

# %%
overall_avg = df['Salary'].mean()
high_earners = df[df['Salary'] > overall_avg]
print(f"Overall average salary: {overall_avg}")
print(f"Number of employees earning above average: {len(high_earners)}")
display(high_earners.head())
# Out:
# Overall average salary: 77760.0
# Number of employees earning above average: 51
#   Employee_ID      Name  Department  Age  Gender  Salary  Experience_Years
# 1        E002    Diana2  Operations   56    Male  105000                27
# 3        E004     Neha4          HR   57    Male  113000                34
# 7        E008     Neha8     Finance   24  Female   98000                 7
# 8        E009    Mohan9          HR   57  Female  110000                23
# 9        E010  Vikram10          IT   26    Male  114000                14

# %% [markdown]
# ## Experiment 1.9: Average Experience per Department

# %%
avg_exp = df.groupby('Department')['Experience_Years'].mean()
print("Average years of experience by department:")
print(avg_exp)
# Out:
# Average years of experience by department:
# Department
# Finance       11.166667
# HR            19.809524
# IT            18.388889
# Marketing     21.900000
# Operations    16.875000
# Sales         23.846154
# Name: Experience_Years, dtype: float64

# %% [markdown]
# ## Experiment 1.10: Age Distribution Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=15, kde=True)
plt.title('Distribution of Employee Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
